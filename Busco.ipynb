# %% [markdown]
# Busco

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:14
# 🔁 Restarting kernel...

# %%
# !conda --version
# Out:
# conda 22.9.0

# %%
# !conda config --add channels bioconda
# !conda config --set channel_priority flexible
# !conda install busco
# Out:
# ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - busco
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bbmap-39.01                |       h5c4e2a8_0         9.0 MB  bioconda
#     busco-5.4.4                |     pyhdfd78af_0         335 KB  bioconda
#     gawk-5.1.0                 |       h7f98852_0         1.4 MB  conda-forge
#     metaeuk-6.a5d39d9          | pl5321hf1761c0_1         4.1 MB  bioconda
#     pandas-1.5.2               |   py38h8f669ce_0        10.3 MB  conda-forge
#     pbzip2-1.1.13              |                0         114 KB  conda-forge
#     python-dateutil-2.8.2      |     pyhd8ed1ab_0         240 KB  conda-forge
#     pytz-2022.7                |     pyhd8ed1ab_0         182 KB  conda-forge
#     samtools-1.16.1            |       h6899075_1         411 KB  bioconda
# ...

# %%
# !conda create -n busco_test
# !conda activate busco_test
# !conda install -c bioconda -c conda-forge busco=4.1.4 augustus=3.3.3
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/busco_test
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate busco_test
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Retrieving notices: ...working... done
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
# done
# ...

# %%
# !busco --list-datasets
# Out:
# INFO:	Downloading information on latest versions of BUSCO data...
# INFO:	Downloading file 'https://busco-data.ezlab.org/v4/data/information/lineages_list.2019-11-27.txt.tar.gz'
# INFO:	Decompressing file '/content/busco_downloads/information/lineages_list.2019-11-27.txt.tar.gz'
#
# ################################################
#
# Datasets available to be used with BUSCOv4 as of 2019/11/27:
#
#  bacteria_odb10
#      - acidobacteria_odb10
#      - actinobacteria_phylum_odb10
#          - actinobacteria_class_odb10
#              - corynebacteriales_odb10
#              - micrococcales_odb10
#              - propionibacteriales_odb10
#              - streptomycetales_odb10
#              - streptosporangiales_odb10
#          - coriobacteriia_odb10
#              - coriobacteriales_odb10
#      - aquificae_odb10
#      - bacteroidetes-chlorobi_group_odb10
#          - bacteroidetes_odb10
#              - bacteroidia_odb10
#                  - bacteroidales_odb10
# ...

# %%
# !busco -c 2 -f -m tran -i /content/Trinity.fasta -o busco_result --lineage_dataset Fabales
# Out:
# 2022-12-27 13:26:43 INFO:	***** Start a BUSCO v5.4.4 analysis, current time: 12/27/2022 13:26:43 *****
# 2022-12-27 13:26:43 INFO:	Configuring BUSCO with local environment
# 2022-12-27 13:26:43 INFO:	Mode is transcriptome
# 2022-12-27 13:26:43 INFO:	'Force' option selected; overwriting previous results directory
# 2022-12-27 13:26:43 INFO:	Downloading information on latest versions of BUSCO data...
# 2022-12-27 13:26:46 INFO:	Input file is /content/Trinity.fasta
# 2022-12-27 13:26:46 INFO:	Downloading file 'https://busco-data.ezlab.org/v5/data/lineages/eudicots_odb10.2020-09-10.tar.gz'
# 2022-12-27 13:26:59 INFO:	Decompressing file '/content/busco_downloads/lineages/eudicots_odb10.tar.gz'
# 2022-12-27 13:27:09 INFO:	Running BUSCO using lineage dataset eudicots_odb10 (eukaryota, 2020-09-10)
# 2022-12-27 13:27:11 INFO:	Running 1 job(s) on metaeuk, starting at 12/27/2022 13:27:11
# 2022-12-27 13:59:13 INFO:	[metaeuk]	1 of 1 task(s) completed
# ...

# %%
#Gvolant result
Fabales (genome): https://gvolante.riken.jp/script/result.cgi?202212271322-EVS3XHDRADB9HG2G
Fabales (transcriptome): https://gvolante.riken.jp/script/result.cgi?202212272129-WVAWFAJVG77W3BLA
Eudicots: https://gvolante.riken.jp/script/result.cgi?202212272039-4CF7U152BUHUPLC7

# %%
#CD-HIT-EST
#https://www.ncbi.nlm.nih.gov/books/NBK569566/
#https://bmcgenomics.biomedcentral.com/articles/10.1186/s12864-022-08449-0

# %%
# util: https://ucdavis-bioinformatics-training.github.io/2020-Genome_Assembly_Workshop/busco/busco

# %%
# !tar -zcvf inga_vera_busco.tar.gz busco_result
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# busco_result/run_eudicots_odb10/busco_sequences/multi_copy_busco_sequences/40951at71240.fna
# busco_result/run_eudicots_odb10/busco_sequences/multi_copy_busco_sequences/149660at71240.fna
# busco_result/run_eudicots_odb10/busco_sequences/multi_copy_busco_sequences/119385at71240.faa
# busco_result/run_eudicots_odb10/busco_sequences/multi_copy_busco_sequences/79753at71240.faa
# busco_result/run_eudicots_odb10/busco_sequences/multi_copy_busco_sequences/96736at71240.faa
# busco_result/run_eudicots_odb10/busco_sequences/multi_copy_busco_sequences/129014at71240.faa
# busco_result/run_eudicots_odb10/busco_sequences/multi_copy_busco_sequences/141773at71240.gff
# busco_result/run_eudicots_odb10/busco_sequences/multi_copy_busco_sequences/150812at71240.gff
# busco_result/run_eudicots_odb10/busco_sequences/multi_copy_busco_sequences/159994at71240.fna
# ...

# %%
# !wget https://gitlab.com/ezlab/busco/-/raw/master/scripts/generate_plot.py
# !mkdir -p summaries
# !cp /content/busco_result/*summary* summaries
# !python3 generate_plot.py -wd summaries
# Out:
# --2022-12-27 16:59:04--  https://gitlab.com/ezlab/busco/-/raw/master/scripts/generate_plot.py
# Resolving gitlab.com (gitlab.com)... 172.65.251.78, 2606:4700:90:0:f22e:fbec:5bed:a9b9
# Connecting to gitlab.com (gitlab.com)|172.65.251.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15603 (15K) [text/plain]
# Saving to: ‘generate_plot.py.1’
#
# generate_plot.py.1  100%[===================>]  15.24K  --.-KB/s    in 0s
#
# 2022-12-27 16:59:04 (71.9 MB/s) - ‘generate_plot.py.1’ saved [15603/15603]
#
# 2022-12-27 16:59:04 INFO:	****************** Start plot generation at 12/27/2022 16:59:04 ******************
# 2022-12-27 16:59:04 INFO:	Load data ...
# 2022-12-27 16:59:04 INFO:	Loaded summaries/short_summary.specific.eudicots_odb10.busco_result.txt successfully
# 2022-12-27 16:59:04 INFO:	Generate the R code ...
# 2022-12-27 16:59:04 INFO:	Run the R code ...
# 2022-12-27 16:59:08 INFO:
# [1] "Plotting the figure ..."
# [1] "Done"
#
# ...
